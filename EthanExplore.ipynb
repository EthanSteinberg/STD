# %%
import numpy as np
import scipy
import sklearn
import lightgbm
import csv
import os
import pandas as pd
import seaborn

# %%
df = pd.read_csv('data/stanford_blueprint_datathon_2019_data.csv')

# %%
uniques = df.nunique()

# %%
print(uniques)
# Out:
# age                                                                                   7
# gender                                                                                2
# state                                                                                51
# income                                                                               36
# education                                                                             5
# high_speed_internet_users                                                             3
# technology_and_connectivity__online_gamers                                        89613
# technology_and_connectivity__stream_music                                         89221
# technology_and_connectivity__science_&_new_tech_enthusiasts                       94113
# technology_and_connectivity__owns_apple_products                                  89897
# technology_and_connectivity__smart_phone_owners                                   85784
# ...

# %%
dates = df.drop_duplicates(subset='date')

# %%
print(dates['date'].sort_values())
# Out:
# 2     2014-01-01
# 14    2014-04-01
# 16    2014-07-01
# 10    2014-10-01
# 3     2015-01-01
# 13    2015-04-01
# 0     2015-07-01
# 19    2015-10-01
# 1     2016-01-01
# 11    2016-04-01
# 20    2016-07-01
# 15    2016-10-01
# 12    2017-01-01
# 5     2017-04-01
# 4     2017-07-01
# 6     2017-10-01
# 17    2018-01-01
# 7     2018-04-01
# 48    2018-07-01
# 18    2018-10-01
# Name: date, dtype: object

# %%
print(df.groupby('date').agg(['count']).sort_values(by='date'))
# Out:
#               age gender  state income education high_speed_internet_users  \
#             count  count  count  count     count                     count
# date
# 2014-01-01  68580  68580  68580  68580     68580                     68574
# 2014-04-01  69399  69399  69399  69399     69399                     69396
# 2014-07-01  69777  69777  69777  69777     69777                     69771
# 2014-10-01  69174  69174  69174  69174     69174                     69170
# 2015-01-01  70024  70024  70024  70024     70024                     70015
# 2015-04-01  70169  70169  70169  70169     70169                     70167
# 2015-07-01  69493  69493  69493  69493     69493                     69490
# 2015-10-01  68894  68894  68894  68894     68894                     68893
# 2016-01-01  70165  70165  70165  70165     70165                     70157
# 2016-04-01  70108  70108  70108  70108     70108                     70104
# ...
